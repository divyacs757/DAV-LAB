# %%
import pandas as pd
df= {
    'name':(['divya','priyanka','chaitra','bhoomika','sanjana']),
    'marks' : ([80,85,45,60,79]),
    'branch' : (['cse','aiml','cse','aiml','cse'])
}
df=pd.DataFrame(df)
print(df)

a=(df[df['marks']>75])
print("who's marks greater then 75\n",a)
#indexing
b=df['marks'][0]
print("0th indexing:",b)

c=df['name']
print("name column:\n",c)

d=df['marks']
print("marks column:\n",d)

e=df['branch']
print("branch column:\n",e)
# Out:
#        name  marks branch
# 0     divya     80    cse
# 1  priyanka     85   aiml
# 2   chaitra     45    cse
# 3  bhoomika     60   aiml
# 4   sanjana     79    cse
# who's marks greater then 75
#         name  marks branch
# 0     divya     80    cse
# 1  priyanka     85   aiml
# 4   sanjana     79    cse
# 0th indexing: 80
# name column:
#  0       divya
# 1    priyanka
# 2     chaitra
# 3    bhoomika
# 4     sanjana
# Name: name, dtype: str
# marks column:
#  0    80
# 1    85
# 2    45
# 3    60
# 4    79
# Name: marks, dtype: int64
# branch column:
#  0     cse
# 1    aiml
# 2     cse
# 3    aiml
# 4     cse
# Name: branch, dtype: str

# %%
print("1st row:\n",df.loc[0])

print("2nd row:\n",df.loc[1])

print("3rd row:\n",df.loc[2])

print("4rt row:\n",df.loc[3])

print("5th row:\n",df.loc[4])
# Out:
# 1st row:
#  name      divya
# marks        80
# branch      cse
# Name: 0, dtype: object
# 2nd row:
#  name      priyanka
# marks           85
# branch        aiml
# Name: 1, dtype: object
# 3rd row:
#  name      chaitra
# marks          45
# branch        cse
# Name: 2, dtype: object
# 4rt row:
#  name      bhoomika
# marks           60
# branch        aiml
# Name: 3, dtype: object
# 5th row:
#  name      sanjana
# marks          79
# branch        cse
# Name: 4, dtype: object
